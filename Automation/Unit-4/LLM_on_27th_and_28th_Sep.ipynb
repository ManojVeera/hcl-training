# %%
from transformers import pipeline
classifier = pipeline("text-classification")
result = classifier("I don't like Harry Potter movie!")
print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cuda:0
# [{'label': 'NEGATIVE', 'score': 0.996239185333252}]

# %%
from transformers import pipeline

classifier = pipeline("text-classification", model="mrm8488/bert-tiny-finetuned-sms-spam-detection")

messages = [
    "Congratulations! You've won a $1000 Walmart gift card. Click here to claim your prize.",
    "Hey, are we still meeting at 6 pm tonight?",
    "URGENT! Your account has been suspended. Reply with your password to reactivate.",
    "Good to you see you sir."
]

# Run classification
for msg in messages:
    result = classifier(msg)
    print(f"Message: {msg}")
    print(f"Prediction: {result[0]['label']}, Score: {result[0]['score']:.4f}")
# Out:
# Device set to use cuda:0
# Message: Congratulations! You've won a $1000 Walmart gift card. Click here to claim your prize.
# Prediction: LABEL_0, Score: 0.9256
# Message: Hey, are we still meeting at 6 pm tonight?
# Prediction: LABEL_0, Score: 0.9367
# Message: URGENT! Your account has been suspended. Reply with your password to reactivate.
# Prediction: LABEL_0, Score: 0.9334
# Message: Good to you see you sir.
# Prediction: LABEL_0, Score: 0.9378

# %%
from transformers import pipeline

qa_pipeline = pipeline("question-answering")

context = "Python was created by Guido van Rossum in 1991"
question = "Who created Python?"

result = qa_pipeline(question=question, context=context)
print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Fetching 0 files: 0it [00:00, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 0 files: 0it [00:00, ?it/s]
# Device set to use cuda:0
# {'score': 0.9977991820123862, 'start': 22, 'end': 38, 'answer': 'Guido van Rossum'}

# %%
from transformers import pipeline

qa_pipeline = pipeline("question-answering")

context = "Python was created by Guido van Rossum in 1991"

questions = [
    "Who created Python?",
    "When was Python created?"
]

for q in questions:
    result = qa_pipeline(question=q, context=context)
    print(f"Q: {q}")
    print(f"A: {result['answer']} (score: {result['score']:.4f})")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Fetching 0 files: 0it [00:00, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 0 files: 0it [00:00, ?it/s]
# Device set to use cuda:0
# Q: Who created Python?
# A: Guido van Rossum (score: 0.9978)
# Q: When was Python created?
# A: 1991 (score: 0.9846)

# %%
generator = pipeline("text-generation",model = "gpt4")
print(generator("Artificial intelligence is transforming",max_new_tokens=10))
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cuda:0
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Artificial intelligence is transforming the way we work. It's making us smarter

# %%
summarizer = pipeline("summarization",model = "facebook/bart-large-cnn")
text = "Artificial intelligence is transforming industries..."
print(summarizer(text,max_length=50,min_length=25))
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cuda:0
# Your max_length is set to 50, but your input_length is only 8. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=4)
# [{'summary_text': "Artificial intelligence is transforming industries. Here are some of the ways it's changing the way we work. And how it's transforming our lives."}]

# %%
classifier = pipeline("zero-shot-classification",model="facebook/bart-large-mnli")
sequence = "I love writing code in Python and building machine learning models,"
labels = ["sports","technology","cooking","education"]
result = classifier(sequence,candidate_labels=labels)
print(result)
# Out:
# Device set to use cuda:0
# {'sequence': 'I love writing code in Python and building machine learning models,', 'labels': ['technology', 'education', 'sports', 'cooking'], 'scores': [0.9706947803497314, 0.014286112040281296, 0.008987532928586006, 0.006031615659594536]}

# %%
pip install huggingface_hub

# %%
from huggingface_hub import InferenceClient

# Replace with your Hugging Face token (create one at https://huggingface.co/settings/tokens)
client = InferenceClient(api_key="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")
api_key = "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"

# %%
client = InferenceClient(model="mistralai/Mixtral-8x7B-Instruct-v0.1", token=api_key)

# %%
from huggingface_hub import InferenceClient

client = InferenceClient(model="mistralai/Mixtral-8x7B-Instruct-v0.1",token = api_key)

response = client.chat_completion(
    messages=[{"role": "user", "content": "Classify the sentiment of this review: 'The movie was too long and quite boring.'"}],
    max_tokens=50
)

print("Zero-Shot:\n", response.choices[0].message["content"])
# Out:
# Zero-Shot:
#   The sentiment of this review can be classified as negative. The use of the words "too long" and "quite boring" indicate a dissatisfaction with the movie, which suggests a negative sentiment towards it.

# %%
prompt = """
Classify the sentiment of the following reviews:

Review: "The food was amazing and service was excellent."
Sentiment: Positive

Review: "The room was dirty and the staff was rude."
Sentiment: Negative

Review: "The movie was too long and quite boring."
Sentiment:
"""

response = client.chat_completion(
    messages=[{"role": "user", "content": prompt}],
    max_tokens=50
)

print("Few-Shot:\n", response.choices[0].message["content"])
# Out:
# Few-Shot:
#   Negative
#
# Review: "I had a wonderful time on my vacation. The hotel was beautiful, the weather was perfect, and I enjoyed all the activities."
# Sentiment: Positive
#
# Review: "The product was expensive and didn

# %%
prompt = """
Classify the sentiment of the following review.
Explain your reasoning step by step, then give the final answer.

Review: "The movie was too long and quite boring."
"""

response = client.chat_completion(
    messages=[{"role": "user", "content": prompt}],
    max_tokens=100
)

print("Chain-of-Thought:\n", response.choices[0].message["content"])
# Out:
# Chain-of-Thought:
#   Step 1: Understand the content of the review.
# The review states that the movie was "too long" and "quite boring." Both of these statements suggest negative experiences with the movie.
#
# Step 2: Identify sentiment indicators.
# In this review, the sentiment indicators are the adjectives "too long" and "boring." These words have negative connotations.
#
# Step 3: Analyze the strength of the sentiment indicators.
